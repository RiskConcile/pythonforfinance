# %%
import importlib
 
if importlib.util.find_spec('fsspec') is None:
  # !pip install fsspec
if importlib.util.find_spec('s3fs') is None:
  # !pip install s3fs
  
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Collecting s3fs
#   Downloading s3fs-0.5.2-py3-none-any.whl (22 kB)
# Collecting aiobotocore>=1.0.1
#   Downloading aiobotocore-1.1.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 5.3 MB/s eta 0:00:011
# Requirement already satisfied: fsspec>=0.8.0 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from s3fs) (0.8.3)
# Collecting botocore<1.17.45,>=1.17.44
#   Downloading botocore-1.17.44-py2.py3-none-any.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 7.8 MB/s eta 0:00:01
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.7.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: wrapt>=1.10.10 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from aiobotocore>=1.0.1->s3fs) (1.11.2)
# Collecting aiohttp>=3.3.1
#   Downloading aiohttp-3.7.3-cp38-cp38-macosx_10_14_x86_64.whl (647 kB)
#      |████████████████████████████████| 647 kB 25.3 MB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting docutils<0.16,>=0.10
#   Using cached docutils-0.15.2-py3-none-any.whl (547 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from botocore<1.17.45,>=1.17.44->aiobotocore>=1.0.1->s3fs) (2.8.1)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from botocore<1.17.45,>=1.17.44->aiobotocore>=1.0.1->s3fs) (1.25.11)
# Requirement already satisfied: typing_extensions>=3.7 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from aioitertools>=0.5.1->aiobotocore>=1.0.1->s3fs) (3.7.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (20.3.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp38-cp38-macosx_10_14_x86_64.whl (49 kB)
#      |████████████████████████████████| 49 kB 9.9 MB/s  eta 0:00:01
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (3.0.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp38-cp38-macosx_10_14_x86_64.whl (124 kB)
#      |████████████████████████████████| 124 kB 29.4 MB/s eta 0:00:01
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: six>=1.5 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.17.45,>=1.17.44->aiobotocore>=1.0.1->s3fs) (1.15.0)
# Requirement already satisfied: idna>=2.0 in /Users/jandespiegeleer/opt/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs) (2.10)
# Installing collected packages: jmespath, docutils, botocore, aioitertools, multidict, yarl, async-timeout, aiohttp, aiobotocore, s3fs
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
# Successfully installed aiobotocore-1.1.2 aiohttp-3.7.3 aioitertools-0.7.1 async-timeout-3.0.1 botocore-1.17.44 docutils-0.15.2 jmespath-0.10.0 multidict-5.1.0 s3fs-0.5.2 yarl-1.6.3

# %% [markdown]
# # Parameters

# %%
nb_paths = 100
nb_paths_on_plot = 10

initial_price = 40.0

start_date = '2019-09-30'
end_date = '2021-09-30'

# %% [markdown]
# # Read data from file

# %%
df_GE = pd.read_excel('s3://lfspf/GE.xlsx')
df_GE.set_index('date', inplace=True)
df_GE.head()
# Out:
#                GE
# date
# 2007-10-23  40.48
# 2007-10-24  40.23
# 2007-10-25  40.16
# 2007-10-26  40.38
# 2007-10-29  40.56

# %% [markdown]
# # Plot historical price

# %%
df_GE.plot(figsize=(15, 5));

# %% [markdown]
# # Calculate historical returns

# %%
df_GE['Returns'] = df_GE['GE'].pct_change()
df_GE.head()
# Out:
#                GE   Returns
# date
# 2007-10-23  40.48       NaN
# 2007-10-24  40.23 -0.006176
# 2007-10-25  40.16 -0.001740
# 2007-10-26  40.38  0.005478
# 2007-10-29  40.56  0.004458

# %% [markdown]
# # Randomly sample new returns

# %%
dates = pd.bdate_range(start_date, end_date)
nb_dates = len(dates)
dates
# Out:
# DatetimeIndex(['2019-09-30', '2019-10-01', '2019-10-02', '2019-10-03',
#                '2019-10-04', '2019-10-07', '2019-10-08', '2019-10-09',
#                '2019-10-10', '2019-10-11',
#                ...
#                '2021-09-17', '2021-09-20', '2021-09-21', '2021-09-22',
#                '2021-09-23', '2021-09-24', '2021-09-27', '2021-09-28',
#                '2021-09-29', '2021-09-30'],
#               dtype='datetime64[ns]', length=524, freq='B')

# %%
sample_source = df_GE['Returns'].values[1:]
sampled_returns = np.random.choice(sample_source, size=(nb_dates-1, nb_paths))
df_returns = pd.DataFrame(sampled_returns, index=dates[1:])
df_returns.head()
# Out:
#                   0         1         2         3         4         5   \
# 2019-10-01 -0.006043 -0.004993  0.034349  0.003801 -0.010081 -0.000940
# 2019-10-02 -0.010764 -0.005727  0.001059  0.021397  0.013249  0.000311
# 2019-10-03 -0.004606 -0.004968 -0.010336  0.013312 -0.001932 -0.020990
# 2019-10-04 -0.020198  0.005307 -0.020143 -0.004778  0.005119  0.017027
# 2019-10-07 -0.014332 -0.005108  0.012668 -0.005563 -0.041147  0.004475
#
#                   6         7         8         9   ...        90        91  \
# 2019-10-01 -0.031991  0.001355  0.007466 -0.009572  ... -0.027550 -0.010764
# 2019-10-02 -0.010553  0.000000  0.012333 -0.007797  ... -0.003362 -0.021739
# 2019-10-03 -0.023819 -0.006533 -0.017199 -0.007339  ... -0.008784 -0.012033
# 2019-10-04  0.007026  0.014550  0.016667  0.010086  ...  0.007752 -0.009688
# 2019-10-07 -0.006547 -0.004895 -0.111419 -0.000582  ...  0.014548  0.003650
#
#                   92        93        94        95        96        97  \
# 2019-10-01  0.040000 -0.001817 -0.010976  0.016780  0.012437 -0.007277
# 2019-10-02 -0.019670  0.002451  0.003973  0.004719  0.006373 -0.005829
# 2019-10-03  0.009447  0.008344  0.003435 -0.001107 -0.008320 -0.015420
# 2019-10-04  0.000000 -0.003190 -0.008424  0.000737  0.008176  0.034442
# 2019-10-07 -0.000495 -0.016082  0.007165 -0.008247 -0.025549  0.003589
#
#                   98        99
# 2019-10-01  0.021616  0.001465
# 2019-10-02 -0.003945 -0.010685
# 2019-10-03 -0.002319  0.016007
# 2019-10-04  0.003753  0.002404
# 2019-10-07  0.026829  0.000000
#
# [5 rows x 100 columns]

# %% [markdown]
# # Transform sampled returns to prices

# %%
df_price = (1 + df_returns).cumprod(axis=0)
df_price.loc[dates[0], :] = 1.0
df_price *= initial_price
df_price.head()
# Out:
#                    0          1          2          3          4          5   \
# 2019-10-01  39.758270  39.800266  41.373947  40.152027  39.596743  39.962406
# 2019-10-02  39.330323  39.572330  41.417775  41.011154  40.121369  39.974817
# 2019-10-03  39.149170  39.375732  40.989684  41.557113  40.043854  39.135726
# 2019-10-04  38.358429  39.584701  40.164031  41.358567  40.248857  39.802084
# 2019-10-07  37.808666  39.382517  40.672827  41.128503  38.592732  39.980196
#
#                    6          7          8          9   ...         90  \
# 2019-10-01  38.720353  40.054219  40.298625  39.617117  ...  38.897990
# 2019-10-02  38.311738  40.054219  40.795641  39.308238  ...  38.767216
# 2019-10-03  37.399192  39.792527  40.093996  39.019760  ...  38.426693
# 2019-10-04  37.661949  40.371519  40.762229  39.413310  ...  38.724574
# 2019-10-07  37.415390  40.173910  36.220555  39.390389  ...  39.287930
#
#                    91         92         93         94         95         96  \
# 2019-10-01  39.569452  41.600000  39.927317  39.560976  40.671195  40.497479
# 2019-10-02  38.709246  40.781726  40.025178  39.718142  40.863140  40.755589
# 2019-10-03  38.243460  41.166978  40.359133  39.854572  40.817888  40.416506
# 2019-10-04  37.872964  41.166978  40.230396  39.518829  40.847989  40.746956
# 2019-10-07  38.011186  41.146589  39.583416  39.801974  40.511099  39.705926
#
#                    97         98         99
# 2019-10-01  39.708904  40.864635  40.058587
# 2019-10-02  39.477440  40.703433  39.630547
# 2019-10-03  38.868690  40.609056  40.264898
# 2019-10-04  40.207425  40.761462  40.361688
# 2019-10-07  40.351745  41.855062  40.361688
#
# [5 rows x 100 columns]

# %% [markdown]
# # Plot some of the sampled paths

# %%
df_price.iloc[:, 0:nb_paths_on_plot].plot(figsize=(15,5))
# Out:
# <AxesSubplot:>
